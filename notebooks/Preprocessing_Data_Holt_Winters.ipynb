# %%
# Import All Necessary Libraries
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.api import ExponentialSmoothing
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# %%
#Import The Dataset
Beras_Import = pd.read_csv("/content/Beras.csv", sep=';')
print(Beras_Import)
# Out:
#      Tahun      Bulan  Harga Beras
# 0   2018.0    Januari     10349.91
# 1      NaN   Februari     10381.74
# 2      NaN      Maret      9892.56
# 3      NaN      April      9524.96
# 4      NaN        Mei      9523.88
# 5      NaN       Juni      9478.05
# 6      NaN       Juli      9519.93
# 7      NaN    Agustus      9458.07
# 8      NaN  September      9572.03
# 9      NaN    Oktober      9645.30
# 10     NaN   November      9770.97
# 11     NaN   Desember      9818.07
# 12  2019.0    Januari     10111.08
# 13     NaN   Februari     10007.91
# 14     NaN      Maret      9814.53
# 15     NaN      April      9464.68
# 16     NaN        Mei      9462.05
# 17     NaN       Juni      9515.51
# 18     NaN       Juli      9519.35
# 19     NaN    Agustus      9530.00
# 20     NaN  September      9594.39
# 21     NaN    Oktober      9659.17
# 22     NaN   November      9742.16
# 23     NaN   Desember      9838.26
# 24  2020.0    Januari     10032.66
# 25     NaN   Februari     10080.80
# 26     NaN      Maret     10082.43
# 27     NaN      April     10018.19
# 28     NaN        Mei      9826.63
# 29     NaN       Juni      9918.95
# 30     NaN       Juli      9931.71
# 31     NaN    Agustus      9962.65
# 32     NaN  September      9871.12
# 33     NaN    Oktober      9812.90
# 34     NaN   November      9714.50
# 35     NaN   Desember      9787.86
# 36  2021.0    Januari      9780.19
# 37     NaN   Februari      9772.10
# 38     NaN      Maret      9606.97
# 39     NaN      April      9549.76
# 40     NaN        Mei      9627.08
# 41     NaN       Juni      9537.16
# 42     NaN       Juli      9401.61
# 43     NaN    Agustus      9499.36
# 44     NaN  September      9455.56
# 45     NaN    Oktober      9449.47
# 46     NaN   November      9539.29
# 47     NaN   Desember      9672.54
# 48  2022.0    Januari      9824.23
# 49     NaN   Februari      9826.88
# 50     NaN      Maret      9786.63
# 51     NaN      April      9576.75
# 52     NaN        Mei      9512.63
# 53     NaN       Juni      9497.40
# 54     NaN       Juli      9628.57
# 55     NaN    Agustus      9901.15
# 56     NaN  September     10252.31
# 57     NaN    Oktober     10402.23
# 58     NaN   November     10511.71
# 59     NaN   Desember     10954.01

# %%
#Change Index of The Data
HB= pd.Series(Beras_Import['Harga Beras'].values, index=pd.date_range(start='2018-01', periods=len(Beras_Import), freq='ME'))
print(HB)

print(HB)
# Out:
# 2018-01-31    10349.91
# 2018-02-28    10381.74
# 2018-03-31     9892.56
# 2018-04-30     9524.96
# 2018-05-31     9523.88
# 2018-06-30     9478.05
# 2018-07-31     9519.93
# 2018-08-31     9458.07
# 2018-09-30     9572.03
# 2018-10-31     9645.30
# 2018-11-30     9770.97
# 2018-12-31     9818.07
# 2019-01-31    10111.08
# 2019-02-28    10007.91
# 2019-03-31     9814.53
# 2019-04-30     9464.68
# 2019-05-31     9462.05
# 2019-06-30     9515.51
# 2019-07-31     9519.35
# 2019-08-31     9530.00
# 2019-09-30     9594.39
# 2019-10-31     9659.17
# 2019-11-30     9742.16
# 2019-12-31     9838.26
# 2020-01-31    10032.66
# 2020-02-29    10080.80
# 2020-03-31    10082.43
# 2020-04-30    10018.19
# 2020-05-31     9826.63
# 2020-06-30     9918.95
# 2020-07-31     9931.71
# 2020-08-31     9962.65
# 2020-09-30     9871.12
# 2020-10-31     9812.90
# 2020-11-30     9714.50
# 2020-12-31     9787.86
# 2021-01-31     9780.19
# 2021-02-28     9772.10
# 2021-03-31     9606.97
# 2021-04-30     9549.76
# 2021-05-31     9627.08
# 2021-06-30     9537.16
# 2021-07-31     9401.61
# 2021-08-31     9499.36
# 2021-09-30     9455.56
# 2021-10-31     9449.47
# 2021-11-30     9539.29
# 2021-12-31     9672.54
# 2022-01-31     9824.23
# 2022-02-28     9826.88
# 2022-03-31     9786.63
# 2022-04-30     9576.75
# 2022-05-31     9512.63
# 2022-06-30     9497.40
# 2022-07-31     9628.57
# 2022-08-31     9901.15
# 2022-09-30    10252.31
# 2022-10-31    10402.23
# 2022-11-30    10511.71
# 2022-12-31    10954.01
# Freq: ME, dtype: float64
# 2018-01-31    10349.91
# 2018-02-28    10381.74
# 2018-03-31     9892.56
# 2018-04-30     9524.96
# 2018-05-31     9523.88
# 2018-06-30     9478.05
# 2018-07-31     9519.93
# 2018-08-31     9458.07
# 2018-09-30     9572.03
# 2018-10-31     9645.30
# 2018-11-30     9770.97
# 2018-12-31     9818.07
# 2019-01-31    10111.08
# 2019-02-28    10007.91
# 2019-03-31     9814.53
# 2019-04-30     9464.68
# 2019-05-31     9462.05
# 2019-06-30     9515.51
# 2019-07-31     9519.35
# 2019-08-31     9530.00
# 2019-09-30     9594.39
# 2019-10-31     9659.17
# 2019-11-30     9742.16
# 2019-12-31     9838.26
# 2020-01-31    10032.66
# 2020-02-29    10080.80
# 2020-03-31    10082.43
# 2020-04-30    10018.19
# 2020-05-31     9826.63
# 2020-06-30     9918.95
# 2020-07-31     9931.71
# 2020-08-31     9962.65
# 2020-09-30     9871.12
# 2020-10-31     9812.90
# 2020-11-30     9714.50
# 2020-12-31     9787.86
# 2021-01-31     9780.19
# 2021-02-28     9772.10
# 2021-03-31     9606.97
# 2021-04-30     9549.76
# 2021-05-31     9627.08
# 2021-06-30     9537.16
# 2021-07-31     9401.61
# 2021-08-31     9499.36
# 2021-09-30     9455.56
# 2021-10-31     9449.47
# 2021-11-30     9539.29
# 2021-12-31     9672.54
# 2022-01-31     9824.23
# 2022-02-28     9826.88
# 2022-03-31     9786.63
# 2022-04-30     9576.75
# 2022-05-31     9512.63
# 2022-06-30     9497.40
# 2022-07-31     9628.57
# 2022-08-31     9901.15
# 2022-09-30    10252.31
# 2022-10-31    10402.23
# 2022-11-30    10511.71
# 2022-12-31    10954.01
# Freq: ME, dtype: float64

# %%
#Visualized the Data
plt.figure(figsize=(10,4))
plt.plot(HB, label='Actual Data', color='#090979')
plt.title("Imported RIce Price")
plt.xlabel("Year")
plt.ylabel("Price")
plt.legend()
plt.show()
